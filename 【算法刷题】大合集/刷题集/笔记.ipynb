# %% [markdown]
# 使用 enumerate: for index, num in enumerate(nums): 可以让我们在循环中非常方便地同时获得索引 index 和值 num，避免了手动管理 index 变量的麻烦和错误。
# ```python
#   for index, num in enumerate(nums):
# ```

# %% [markdown]
# defaultdict(int) 是一个方便的工具，当我们访问一个不存在的键时，它会自动用 int()（也就是 0）来创建这个键，避免了代码出错。
#
# ![20260129044149](https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129044149.png)
#
# 优化后
#
# ![20260129044228](https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129044228.png)
#
# ```python
#  map=defaultdict(int)
#         methods=0
#         for i in nums1:
#             for j in nums2:
#                     map[i+j]+=1
# ```
