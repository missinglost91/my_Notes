# %%
#

# %% [markdown]
# <img src="https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129015635.png" alt="20260129015635"  style="width: 500px " />
# <br>
#
#
# <img src="https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129020626.png" alt="20260129015635"  style="width: 500px " />
#
# 哈希冲突
# ![20260129021208](https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129021208.png)
#
# 拉链法
# ![20260129021325](https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129021325.png)
# ![20260129021848](https://lin01-image-1373317342.cos.ap-beijing.myqcloud.com/20260129021848.png)

# %%
de

# %%
def sum_fun(x):
    result=0
    while (x>=10):
            result+=pow(x%10,2)
            x=x//10
    result+=pow(x,2)
    return result

sum_fun(123)
# Out:
# 14
