# %%
import cv2   #opencv读取的格式是BGR
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

img=cv2.imread('pig.jpg')

def cv_show(name,img):
    cv2.imshow('pig',img)  #image弹出的图片展示窗口名称，img为对象名
    cv2.waitKey(0)   #按任意键退出
    cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (672, 632, 3)

# %%
img=cv2.imread('pig.jpg',cv2.IMREAD_GRAYSCALE)  #以灰度图的方式读取
cv_show(img,img)  #调用我们自己定义的函数cv_show

# %%
cv2.imwrite("pig-gray.jpg",img) #图像保存
# Out:
# True

# %%
img.size #像素点数
# Out:
# 424704

# %%
img.dtype #数据类型
# Out:
# dtype('uint8')

# %%
type(img) #数据类型
# Out:
# numpy.ndarray
