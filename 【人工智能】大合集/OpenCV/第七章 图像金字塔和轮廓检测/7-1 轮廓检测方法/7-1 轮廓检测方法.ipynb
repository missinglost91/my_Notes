# %%
import cv2  #opencv读取的格式是BGR
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.image import imread
# %matplotlib inline

def cv_show(name, img):
    cv2.imshow(name, img)  #image弹出的图片展示窗口名称，img为对象名
    cv2.waitKey(0)  #按任意键退出
    cv2.destroyAllWindows()

img_dog=cv2.imread('dog.png', cv2.IMREAD_GRAYSCALE)

# %%
ret,thresh=cv2.threshold(img_dog,127,255,cv2.THRESH_BINARY) #用阈值处理转化为二值图像
plt.imshow(thresh,'gray')

# %%
coutours,hierarchy=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
# contours: 检测到的轮廓列表。
# hierarchy: 轮廓的层次结构信息

# %%
#菜鸟实例


image = cv2.imread("lena.jpg")

# 转换为灰度图
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 二值化处理
ret, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# 查找轮廓
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# 绘制轮廓
cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

# 显示结果
cv2.imshow("Contours", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
